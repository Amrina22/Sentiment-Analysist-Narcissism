# %% [markdown]
# ## Importing Necessary Libraries

# %%
import pandas as pd
import html
import pandas as pd
from googletrans import Translator

# %% [markdown]
# ## Loading Dataset

# %%
df = pd.read_csv(r'Data\narcissism_dataset.csv')
df.head()
# Out:
#    conversation_id_str                      created_at  favorite_count  \
# 0         1.800000e+18  Fri Jun 14 06:00:09 +0000 2024           20853
# 1         1.800000e+18  Fri Jun 14 01:44:55 +0000 2024           46197
# 2         1.800000e+18  Thu Jun 13 06:19:50 +0000 2024            1670
# 3         1.800000e+18  Mon Jun 17 15:25:10 +0000 2024            4855
# 4         1.800000e+18  Thu Jun 13 10:38:04 +0000 2024             288
#
#                                            full_text        id_str  \
# 0  &lt; NARCISSISM : JAEMIN 1st PHOTO EXHIBITION ...  1.800000e+18
# 1  #NCT #재민 첫 개인 사진전 #NARCISSISM 6월 29일오픈! 사진 작가로...  1.800000e+18
# 2  NARCISSISM PHOTOGRAPHER NA JAEMIN 1st PHOTO EX...  1.800000e+18
# 3  Jaemin got casted while volunteering and till ...  1.800000e+18
# 4  ️ Mini Support Project for &lt; NARCISSISM @NA...  1.800000e+18
#
#                                          image_url in_reply_to_screen_name  \
# 0  https://pbs.twimg.com/media/GQAx-8IaQAEokgq.jpg                     NaN
# 1  https://pbs.twimg.com/media/GP_3kPybUAA65sV.jpg                     NaN
# 2  https://pbs.twimg.com/media/GP7s51absAAf4tq.jpg                     NaN
# 3  https://pbs.twimg.com/media/GQSQEzcboAA6NhK.jpg                     NaN
# 4  https://pbs.twimg.com/media/GP8oAUPbwAAoYNu.jpg                     NaN
#
#   lang       location  quote_count  reply_count  retweet_count  \
# 0   ko            NaN          355          475          13150
# 1   ko            NaN         3011         1600          27395
# 2   en       재민 제노 잼젠           57            0           1023
# 3   en         akgae           109            8           2423
# 4   ko  🐰 항상 재민이 옆에 🐱           32            1            255
#
#                                            tweet_url   user_id_str  \
# 0  https://x.com/NCTsmtown/status/180149481786990...  4.811011e+09
# 1  https://x.com/NCTsmtown/status/180143058501101...  4.811011e+09
# 2  https://x.com/jamong1323/status/18011373840522...  1.420000e+18
# 3  https://x.com/user13082000_/status/18027241739...  1.470000e+18
# 4  https://x.com/najaeminnesia/status/18012023710...  1.340000e+18
#
#         username
# 0      NCTsmtown
# 1      NCTsmtown
# 2     jamong1323
# 3  user13082000_
# 4  najaeminnesia

# %% [markdown]
# # Initial Data Analysis

# %% [markdown]
# ### Dataset Overview

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1139 entries, 0 to 1138
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   conversation_id_str      1139 non-null   float64
#  1   created_at               1139 non-null   object
#  2   favorite_count           1139 non-null   int64
#  3   full_text                1139 non-null   object
#  4   id_str                   1139 non-null   float64
#  5   image_url                1030 non-null   object
#  6   in_reply_to_screen_name  68 non-null     object
#  7   lang                     1139 non-null   object
#  8   location                 782 non-null    object
#  9   quote_count              1139 non-null   int64
#  10  reply_count              1139 non-null   int64
#  11  retweet_count            1139 non-null   int64
#  12  tweet_url                1139 non-null   object
#  13  user_id_str              1139 non-null   float64
#  14  username                 1139 non-null   object
# dtypes: float64(3), int64(4), object(8)
# memory usage: 133.6+ KB

# %% [markdown]
# ### Handling Missing Values

# %%
df.isnull().sum()
# Out:
# conversation_id_str           0
# created_at                    0
# favorite_count                0
# full_text                     0
# id_str                        0
# image_url                   109
# in_reply_to_screen_name    1071
# lang                          0
# location                    357
# quote_count                   0
# reply_count                   0
# retweet_count                 0
# tweet_url                     0
# user_id_str                   0
# username                      0
# dtype: int64

# %%
df.drop(df.columns[[5,6,8]],axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# conversation_id_str    0
# created_at             0
# favorite_count         0
# full_text              0
# id_str                 0
# lang                   0
# quote_count            0
# reply_count            0
# retweet_count          0
# tweet_url              0
# user_id_str            0
# username               0
# dtype: int64

# %% [markdown]
# ### Handling Duplicates

# %%
df.drop_duplicates()
# Out:
#       conversation_id_str                      created_at  favorite_count  \
# 0            1.800000e+18  Fri Jun 14 06:00:09 +0000 2024           20853
# 1            1.800000e+18  Fri Jun 14 01:44:55 +0000 2024           46197
# 2            1.800000e+18  Thu Jun 13 06:19:50 +0000 2024            1670
# 3            1.800000e+18  Mon Jun 17 15:25:10 +0000 2024            4855
# 4            1.800000e+18  Thu Jun 13 10:38:04 +0000 2024             288
# ...                   ...                             ...             ...
# 1134         1.814830e+18  Sun Jul 21 01:07:42 +0000 2024               6
# 1135         1.814820e+18  Sun Jul 21 00:40:49 +0000 2024               0
# 1136         1.814830e+18  Sun Jul 21 00:54:23 +0000 2024               0
# 1137         1.814810e+18  Sun Jul 21 00:00:23 +0000 2024               0
# 1138         1.814550e+18  Sun Jul 21 00:01:27 +0000 2024               0
#
#                                               full_text        id_str lang  \
# 0     &lt; NARCISSISM : JAEMIN 1st PHOTO EXHIBITION ...  1.800000e+18   ko
# 1     #NCT #재민 첫 개인 사진전 #NARCISSISM 6월 29일오픈! 사진 작가로...  1.800000e+18   ko
# 2     NARCISSISM PHOTOGRAPHER NA JAEMIN 1st PHOTO EX...  1.800000e+18   en
# 3     Jaemin got casted while volunteering and till ...  1.800000e+18   en
# 4     ️ Mini Support Project for &lt; NARCISSISM @NA...  1.800000e+18   ko
# ...                                                 ...           ...  ...
# 1134  DAY 23 ‼️ JAEMIN PHOTOGRAPHER DEBUT #JAEMIN_NA...  1.814830e+18   en
# 1135  &gt; day-23 with 𝐍𝐀𝐑𝐂𝐈𝐒𝐒𝐈𝐒𝐌 PHOTOGRAPHER JAEMI...  1.814820e+18   en
# 1136  D23 when in London PHOTOGRAPHER JAEMIN #JAEMIN...  1.814830e+18   en
# 1137   우리는 4센터가 트위터(x)와 웨이보 등의 플랫폼에서 재민이가 SnackPaper...  1.814810e+18   ko
# 1138  @juumarn @NA_RCISSISM_ PHOTOGRAPHER JAEMIN #JA...  1.814810e+18   en
#
#       quote_count  reply_count  retweet_count  \
# 0             355          475          13150
# 1            3011         1600          27395
# 2              57            0           1023
# 3             109            8           2423
# 4              32            1            255
# ...           ...          ...            ...
# 1134            0           11              0
# 1135            0            7              0
# 1136            0            0              0
# 1137            0            0              0
# 1138            0            0              0
#
#                                               tweet_url   user_id_str  \
# 0     https://x.com/NCTsmtown/status/180149481786990...  4.811011e+09
# 1     https://x.com/NCTsmtown/status/180143058501101...  4.811011e+09
# 2     https://x.com/jamong1323/status/18011373840522...  1.420000e+18
# 3     https://x.com/user13082000_/status/18027241739...  1.470000e+18
# 4     https://x.com/najaeminnesia/status/18012023710...  1.340000e+18
# ...                                                 ...           ...
# 1134  https://x.com/nayaka_nana/status/1814829570379...  1.700840e+18
# 1135  https://x.com/nanarisjae/status/18148228052441...  1.600080e+18
# 1136   https://x.com/0614day/status/1814826221064364535  2.161853e+09
# 1137  https://x.com/marinatedchick_/status/181481262...  1.483280e+18
# 1138    https://x.com/yyleog/status/1814812899879366810  1.188640e+18
#
#              username
# 0           NCTsmtown
# 1           NCTsmtown
# 2          jamong1323
# 3       user13082000_
# 4       najaeminnesia
# ...               ...
# 1134      nayaka_nana
# 1135       nanarisjae
# 1136          0614day
# 1137  marinatedchick_
# 1138           yyleog
#
# [1139 rows x 12 columns]

# %%
df = df.drop_duplicates(subset=['full_text'])

# %% [markdown]
# ### Handling Unnecessary Words

# %%
# Kata-kata yang ingin dihapus
kata_dihapus = ['po', 'pre order', 'md', 'wtb', 'want to buy', 'iso', 'open']

# Fungsi lambda untuk menghapus kata
def hapus_kata(text):
  for kata in kata_dihapus:
    text = text.replace(kata, '')
  return text

# Hapus kata-kata menggunakan lambda
df['full_text'] = df['full_text'].apply(hapus_kata)

# Cetak hasil
df
# Out:
#       conversation_id_str                      created_at  favorite_count  \
# 0            1.800000e+18  Fri Jun 14 06:00:09 +0000 2024           20853
# 1            1.800000e+18  Fri Jun 14 01:44:55 +0000 2024           46197
# 2            1.800000e+18  Thu Jun 13 06:19:50 +0000 2024            1670
# 3            1.800000e+18  Mon Jun 17 15:25:10 +0000 2024            4855
# 4            1.800000e+18  Thu Jun 13 10:38:04 +0000 2024             288
# ...                   ...                             ...             ...
# 1134         1.814830e+18  Sun Jul 21 01:07:42 +0000 2024               6
# 1135         1.814820e+18  Sun Jul 21 00:40:49 +0000 2024               0
# 1136         1.814830e+18  Sun Jul 21 00:54:23 +0000 2024               0
# 1137         1.814810e+18  Sun Jul 21 00:00:23 +0000 2024               0
# 1138         1.814550e+18  Sun Jul 21 00:01:27 +0000 2024               0
#
#                                               full_text        id_str lang  \
# 0     &lt; NARCISSISM : JAEMIN 1st PHOTO EXHIBITION ...  1.800000e+18   ko
# 1     #NCT #재민 첫 개인 사진전 #NARCISSISM 6월 29일오픈! 사진 작가로...  1.800000e+18   ko
# 2     NARCISSISM PHOTOGRAPHER NA JAEMIN 1st PHOTO EX...  1.800000e+18   en
# 3     Jaemin got casted while volunteering and till ...  1.800000e+18   en
# 4     ️ Mini Suprt Project for &lt; NARCISSISM @NA_R...  1.800000e+18   ko
# ...                                                 ...           ...  ...
# 1134  DAY 23 ‼️ JAEMIN PHOTOGRAPHER DEBUT #JAEMIN_NA...  1.814830e+18   en
# 1135  &gt; day-23 with 𝐍𝐀𝐑𝐂𝐈𝐒𝐒𝐈𝐒𝐌 PHOTOGRAPHER JAEMI...  1.814820e+18   en
# 1136  D23 when in London PHOTOGRAPHER JAEMIN #JAEMIN...  1.814830e+18   en
# 1137   우리는 4센터가 트위터(x)와 웨이보 등의 플랫폼에서 재민이가 SnackPaper...  1.814810e+18   ko
# 1138  @juumarn @NA_RCISSISM_ PHOTOGRAPHER JAEMIN #JA...  1.814810e+18   en
#
#       quote_count  reply_count  retweet_count  \
# 0             355          475          13150
# 1            3011         1600          27395
# 2              57            0           1023
# 3             109            8           2423
# 4              32            1            255
# ...           ...          ...            ...
# 1134            0           11              0
# 1135            0            7              0
# 1136            0            0              0
# 1137            0            0              0
# 1138            0            0              0
#
#                                               tweet_url   user_id_str  \
# 0     https://x.com/NCTsmtown/status/180149481786990...  4.811011e+09
# 1     https://x.com/NCTsmtown/status/180143058501101...  4.811011e+09
# 2     https://x.com/jamong1323/status/18011373840522...  1.420000e+18
# 3     https://x.com/user13082000_/status/18027241739...  1.470000e+18
# 4     https://x.com/najaeminnesia/status/18012023710...  1.340000e+18
# ...                                                 ...           ...
# 1134  https://x.com/nayaka_nana/status/1814829570379...  1.700840e+18
# 1135  https://x.com/nanarisjae/status/18148228052441...  1.600080e+18
# 1136   https://x.com/0614day/status/1814826221064364535  2.161853e+09
# 1137  https://x.com/marinatedchick_/status/181481262...  1.483280e+18
# 1138    https://x.com/yyleog/status/1814812899879366810  1.188640e+18
#
#              username
# 0           NCTsmtown
# 1           NCTsmtown
# 2          jamong1323
# 3       user13082000_
# 4       najaeminnesia
# ...               ...
# 1134      nayaka_nana
# 1135       nanarisjae
# 1136          0614day
# 1137  marinatedchick_
# 1138           yyleog
#
# [1134 rows x 12 columns]

# %% [markdown]
# ### Handling Unnecessary Pattern and Character

# %%
# Decode HTML entities
df['full_text'] = df['full_text'].apply(html.unescape)

# Pola regex untuk menghilangkan URL, retweet, hashtag, dan tag
patterns = [
    r'https?://\S+',  # URL
    r'RT\s@\w+',      # Retweet
    r'#\S+',          # Hashtag
    r'@\S+',          # Tag
]

# Menghilangkan pola dari 'full_text' dan menambahkan spasi setelah penghapusan
for pattern in patterns:
    df['full_text'] = df['full_text'].str.replace(pattern, ' ', regex=True)

# Pola regex untuk menghilangkan karakter khusus dengan menggantinya dengan spasi
special_chars_pattern = r'[!?:;<>!!-._,()x⋆｡˚⋆⁠ө⭐️️.◜◡◝ꔛ𖦹/ᐢ⑅ᐢ꒰˶༝˶꒱./づ~⑅˚₊̷ ⃣ع˖⁺≽^ɞ̴̶̷ ̫ ɞ̴̶̷^≼⋆ㅠㅡㅠ=ᵕ=𝄃𝄃𝄂𝄂𝄀𝄁𝄃𝄂𝄂𝄃]'

# Menghilangkan karakter khusus dan menggantinya dengan spasi
df['full_text'] = df['full_text'].str.replace(special_chars_pattern, ' ', regex=True)

# Menghapus spasi kosong yang berlebih dan mengganti beberapa spasi dengan satu spasi
df['full_text'] = df['full_text'].str.replace(r'\s+', ' ', regex=True).str.strip()

# Menampilkan hasilnya
print(df['full_text'])
# Out:
# 0       NARCISSISM JAEMIN 1st PHOTO EXHIBITION OPEN 29...
# 1       첫 개인 사진전 6월 29일오픈 사진 작가로 데뷔 재민의 독창적인 감성으로 팬들과 ...
# 2       NARCISSISM PHOTOGRAPHER NA JAEMIN 1st PHOTO EX...
# 3       Jaemin got casted while volunteering and till ...
# 4       Mini Suprt Project for NARCISSISM JAEMIN 1st P...
#                               ...
# 1134                   DAY 23 ‼ JAEMIN PHOTOGRAPHER DEBUT
# 1135    day 23 with 𝐍𝐀𝐑𝐂𝐈𝐒𝐒𝐈𝐒𝐌 PHOTOGRAPHER JAEMIN 1ST...
# 1136               D23 when in London PHOTOGRAPHER JAEMIN
# 1137    우리는 4센터가 트위터 와 웨이보 등의 플랫폼에서 재민이가 SnackPaper의 B...
# 1138                                  PHOTOGRAPHER JAEMIN
# Name: full_text, Length: 1134, dtype: object

# %% [markdown]
# ### Translating Column Target

# %%
def translate_text(text, target_language='en'):
    translator = Translator()
    try:
        translation = translator.translate(text, dest=target_language).text
    except Exception as e:
        print(f"Error translating: {e}")
        translation = text  # Or handle errors as needed
    return translation

# %%
# Assuming a column named 'text' contains the text to be translated
df['translated_text'] = df['full_text'].apply(translate_text)

# %%
df
# Out:
#       conversation_id_str                      created_at  favorite_count  \
# 0            1.800000e+18  Fri Jun 14 06:00:09 +0000 2024           20853
# 1            1.800000e+18  Fri Jun 14 01:44:55 +0000 2024           46197
# 2            1.800000e+18  Thu Jun 13 06:19:50 +0000 2024            1670
# 3            1.800000e+18  Mon Jun 17 15:25:10 +0000 2024            4855
# 4            1.800000e+18  Thu Jun 13 10:38:04 +0000 2024             288
# ...                   ...                             ...             ...
# 1134         1.814830e+18  Sun Jul 21 01:07:42 +0000 2024               6
# 1135         1.814820e+18  Sun Jul 21 00:40:49 +0000 2024               0
# 1136         1.814830e+18  Sun Jul 21 00:54:23 +0000 2024               0
# 1137         1.814810e+18  Sun Jul 21 00:00:23 +0000 2024               0
# 1138         1.814550e+18  Sun Jul 21 00:01:27 +0000 2024               0
#
#                                               full_text        id_str lang  \
# 0     NARCISSISM JAEMIN 1st PHOTO EXHIBITION OPEN 29...  1.800000e+18   ko
# 1     첫 개인 사진전 6월 29일오픈 사진 작가로 데뷔 재민의 독창적인 감성으로 팬들과 ...  1.800000e+18   ko
# 2     NARCISSISM PHOTOGRAPHER NA JAEMIN 1st PHOTO EX...  1.800000e+18   en
# 3     Jaemin got casted while volunteering and till ...  1.800000e+18   en
# 4     Mini Suprt Project for NARCISSISM JAEMIN 1st P...  1.800000e+18   ko
# ...                                                 ...           ...  ...
# 1134                 DAY 23 ‼ JAEMIN PHOTOGRAPHER DEBUT  1.814830e+18   en
# 1135  day 23 with 𝐍𝐀𝐑𝐂𝐈𝐒𝐒𝐈𝐒𝐌 PHOTOGRAPHER JAEMIN 1ST...  1.814820e+18   en
# 1136             D23 when in London PHOTOGRAPHER JAEMIN  1.814830e+18   en
# 1137  우리는 4센터가 트위터 와 웨이보 등의 플랫폼에서 재민이가 SnackPaper의 B...  1.814810e+18   ko
# 1138                                PHOTOGRAPHER JAEMIN  1.814810e+18   en
#
#       quote_count  reply_count  retweet_count  \
# 0             355          475          13150
# 1            3011         1600          27395
# 2              57            0           1023
# 3             109            8           2423
# 4              32            1            255
# ...           ...          ...            ...
# 1134            0           11              0
# 1135            0            7              0
# 1136            0            0              0
# 1137            0            0              0
# 1138            0            0              0
#
#                                               tweet_url   user_id_str  \
# 0     https://x.com/NCTsmtown/status/180149481786990...  4.811011e+09
# 1     https://x.com/NCTsmtown/status/180143058501101...  4.811011e+09
# 2     https://x.com/jamong1323/status/18011373840522...  1.420000e+18
# 3     https://x.com/user13082000_/status/18027241739...  1.470000e+18
# 4     https://x.com/najaeminnesia/status/18012023710...  1.340000e+18
# ...                                                 ...           ...
# 1134  https://x.com/nayaka_nana/status/1814829570379...  1.700840e+18
# 1135  https://x.com/nanarisjae/status/18148228052441...  1.600080e+18
# 1136   https://x.com/0614day/status/1814826221064364535  2.161853e+09
# 1137  https://x.com/marinatedchick_/status/181481262...  1.483280e+18
# 1138    https://x.com/yyleog/status/1814812899879366810  1.188640e+18
#
#              username                                    translated_text
# 0           NCTsmtown  NARCISSISM JAEMIN 1st PHOTO EXHIBITION OPEN 29...
# 1           NCTsmtown  First solo photo exhibition opens on June 29 D...
# 2          jamong1323  NARCISSISM PHOTOGRAPHER NA JAEMIN 1st PHOTO EX...
# 3       user13082000_  Jaemin got casted while volunteering and till ...
# 4       najaeminnesia  Mini Suprt Project for NARCISSISM JAEMIN 1st P...
# ...               ...                                                ...
# 1134      nayaka_nana                 DAY 23 ‼ JAEMIN PHOTOGRAPHER DEBUT
# 1135       nanarisjae  day 23 with 𝐍𝐀𝐑𝐂𝐈𝐒𝐒𝐈𝐒𝐌 PHOTOGRAPHER JAEMIN 1ST...
# 1136          0614day             D23 when in London PHOTOGRAPHER JAEMIN
# 1137  marinatedchick_  We hope that 4Center will sufficiently promote...
# 1138           yyleog                                PHOTOGRAPHER JAEMIN
#
# [1134 rows x 13 columns]

# %%
df.to_csv('Data/data_clean.csv')

# %% [markdown]
# ## Importing Necessary Libraries

# %%
import pandas as pd
import numpy as np
import re
import joblib
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from gensim.models import Word2Vec
from transformers import BertTokenizer
from wordcloud import WordCloud
from textblob import TextBlob
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical

nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# WARNING:tensorflow:From C:\Users\AMRINA\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\AMRINA\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\AMRINA\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# ## Loading Dataset

# %%
df_clean = pd.read_csv('Data/data_clean.csv')
df_clean
# Out:
#       Unnamed: 0  conversation_id_str                      created_at  \
# 0              0         1.800000e+18  Fri Jun 14 06:00:09 +0000 2024
# 1              1         1.800000e+18  Fri Jun 14 01:44:55 +0000 2024
# 2              2         1.800000e+18  Thu Jun 13 06:19:50 +0000 2024
# 3              3         1.800000e+18  Mon Jun 17 15:25:10 +0000 2024
# 4              4         1.800000e+18  Thu Jun 13 10:38:04 +0000 2024
# ...          ...                  ...                             ...
# 1256        1261         1.820000e+18  Tue Jul 30 00:04:09 +0000 2024
# 1257        1262         1.820000e+18  Tue Jul 30 00:04:20 +0000 2024
# 1258        1263         1.820000e+18  Tue Jul 30 00:00:10 +0000 2024
# 1259        1264         1.820000e+18  Tue Jul 30 00:04:13 +0000 2024
# 1260        1265         1.820000e+18  Tue Jul 30 00:04:55 +0000 2024
#
#       favorite_count                                          full_text  \
# 0              20853  NARCISSISM JAEMIN 1st PHOTO EXHIBITION OPEN 29...
# 1              46197  첫 개인 사진전 6월 29일오픈 사진 작가로 데뷔 재민의 독창적인 감성으로 팬들과 ...
# 2               1670  NARCISSISM PHOTOGRAPHER NA JAEMIN 1st PHOTO EX...
# 3               4855  Jaemin got casted while volunteering and till ...
# 4                288  Mini Suprt Project for NARCISSISM JAEMIN 1st P...
# ...              ...                                                ...
# 1256               0                            NARCISSISM BY NA JAEMIN
# 1257               0                            NARCISSISM BY NA JAEMIN
# 1258               0                       D 32 NARCISSISM BY NA JAEMIN
# 1259               0                            NARCISSISM BY NA JAEMIN
# 1260               0  ใกล้จะจบนิทรรศการแล้วค้าบบบ ต้องคิดถึงมากแน่ ๆ...
#
#             id_str lang  quote_count  reply_count  retweet_count  \
# 0     1.800000e+18   ko          355          475          13150
# 1     1.800000e+18   ko         3011         1600          27395
# 2     1.800000e+18   en           57            0           1023
# 3     1.800000e+18   en          109            8           2423
# 4     1.800000e+18   ko           32            1            255
# ...            ...  ...          ...          ...            ...
# 1256  1.820000e+18   tl            0            0              0
# 1257  1.820000e+18   tl            0            0              0
# 1258  1.820000e+18   tl            0            0              0
# 1259  1.820000e+18   tl            0            0              0
# 1260  1.820000e+18   th            0            0              0
#
#                                               tweet_url   user_id_str  \
# 0     https://x.com/NCTsmtown/status/180149481786990...  4.811011e+09
# 1     https://x.com/NCTsmtown/status/180143058501101...  4.811011e+09
# 2     https://x.com/jamong1323/status/18011373840522...  1.420000e+18
# 3     https://x.com/user13082000_/status/18027241739...  1.470000e+18
# 4     https://x.com/najaeminnesia/status/18012023710...  1.340000e+18
# ...                                                 ...           ...
# 1256  https://x.com/user13082000_/status/18180750710...  1.470000e+18
# 1257  https://x.com/Sailorneww/status/18180751175175...  4.739379e+08
# 1258    https://x.com/jlynrj/status/1818074066542272684  1.430000e+18
# 1259  https://x.com/ffrongg_/status/1818075085485523352  1.260000e+18
# 1260   https://x.com/Juvliae/status/1818075260652318896  1.700000e+18
#
#            username                                    translated_text
# 0         NCTsmtown  NARCISSISM JAEMIN 1st PHOTO EXHIBITION OPEN 29...
# 1         NCTsmtown  First solo photo exhibition opens on June 29 D...
# 2        jamong1323  NARCISSISM PHOTOGRAPHER NA JAEMIN 1st PHOTO EX...
# 3     user13082000_  Jaemin got casted while volunteering and till ...
# 4     najaeminnesia  Mini Suprt Project for NARCISSISM JAEMIN 1st P...
# ...             ...                                                ...
# 1256  user13082000_                            NARCISSISM BY NA JAEMIN
# 1257     Sailorneww                            NARCISSISM BY NA JAEMIN
# 1258         jlynrj                       D 32 NARCISSISM BY NA JAEMIN
# 1259       ffrongg_                            NARCISSISM BY NA JAEMIN
# 1260        Juvliae  It's almost the end of the exhibition. I will ...
#
# [1261 rows x 14 columns]

# %% [markdown]
# ## Data Preprocessing

# %%
# Defining dictionary containing all emojis with their meanings.
emojis = {':)': 'smile', ':-)': 'smile', ';d': 'wink', ':-E': 'vampire', ':(': 'sad', 
          ':-(': 'sad', ':-<': 'sad', ':P': 'raspberry', ':O': 'surprised',
          ':-@': 'shocked', ':@': 'shocked',':-$': 'confused', ':\\': 'annoyed', 
          ':#': 'mute', ':X': 'mute', ':^)': 'smile', ':-&': 'confused', '$_$': 'greedy',
          '@@': 'eyeroll', ':-!': 'confused', ':-D': 'smile', ':-0': 'yell', 'O.o': 'confused',
          '<(-_-)>': 'robot', 'd[-_-]b': 'dj', ":'-)": 'sadsmile', ';)': 'wink', 
          ';-)': 'wink', 'O:-)': 'angel','O*-)': 'angel','(:-D': 'gossip', '=^.^=': 'cat'}

# %%
def remove_emojis(text):
    if isinstance(text, str):  # Check if it's a string
        for emoji in emojis:
            text = text.replace(emoji, '')
            return text

# %%
df_clean['translated_text'] = df_clean['translated_text'].apply(remove_emojis)

# %%
def clean_text(df, column_name):
    df[column_name] = df[column_name].fillna('').astype(str).str.replace(r'(.)\1', r'\1', regex=True)
    df[column_name] = df[column_name].str.replace(r'[^a-zA-Z0-9]', ' ', regex=True)  # Apply non-alphanumeric replacement
    return df

# %%
df_clean = clean_text(df_clean.copy(), 'translated_text')

# %%
df_clean
# Out:
#       Unnamed: 0  conversation_id_str                      created_at  \
# 0              0         1.800000e+18  Fri Jun 14 06:00:09 +0000 2024
# 1              1         1.800000e+18  Fri Jun 14 01:44:55 +0000 2024
# 2              2         1.800000e+18  Thu Jun 13 06:19:50 +0000 2024
# 3              3         1.800000e+18  Mon Jun 17 15:25:10 +0000 2024
# 4              4         1.800000e+18  Thu Jun 13 10:38:04 +0000 2024
# ...          ...                  ...                             ...
# 1256        1261         1.820000e+18  Tue Jul 30 00:04:09 +0000 2024
# 1257        1262         1.820000e+18  Tue Jul 30 00:04:20 +0000 2024
# 1258        1263         1.820000e+18  Tue Jul 30 00:00:10 +0000 2024
# 1259        1264         1.820000e+18  Tue Jul 30 00:04:13 +0000 2024
# 1260        1265         1.820000e+18  Tue Jul 30 00:04:55 +0000 2024
#
#       favorite_count                                          full_text  \
# 0              20853  NARCISSISM JAEMIN 1st PHOTO EXHIBITION OPEN 29...
# 1              46197  첫 개인 사진전 6월 29일오픈 사진 작가로 데뷔 재민의 독창적인 감성으로 팬들과 ...
# 2               1670  NARCISSISM PHOTOGRAPHER NA JAEMIN 1st PHOTO EX...
# 3               4855  Jaemin got casted while volunteering and till ...
# 4                288  Mini Suprt Project for NARCISSISM JAEMIN 1st P...
# ...              ...                                                ...
# 1256               0                            NARCISSISM BY NA JAEMIN
# 1257               0                            NARCISSISM BY NA JAEMIN
# 1258               0                       D 32 NARCISSISM BY NA JAEMIN
# 1259               0                            NARCISSISM BY NA JAEMIN
# 1260               0  ใกล้จะจบนิทรรศการแล้วค้าบบบ ต้องคิดถึงมากแน่ ๆ...
#
#             id_str lang  quote_count  reply_count  retweet_count  \
# 0     1.800000e+18   ko          355          475          13150
# 1     1.800000e+18   ko         3011         1600          27395
# 2     1.800000e+18   en           57            0           1023
# 3     1.800000e+18   en          109            8           2423
# 4     1.800000e+18   ko           32            1            255
# ...            ...  ...          ...          ...            ...
# 1256  1.820000e+18   tl            0            0              0
# 1257  1.820000e+18   tl            0            0              0
# 1258  1.820000e+18   tl            0            0              0
# 1259  1.820000e+18   tl            0            0              0
# 1260  1.820000e+18   th            0            0              0
#
#                                               tweet_url   user_id_str  \
# 0     https://x.com/NCTsmtown/status/180149481786990...  4.811011e+09
# 1     https://x.com/NCTsmtown/status/180143058501101...  4.811011e+09
# 2     https://x.com/jamong1323/status/18011373840522...  1.420000e+18
# 3     https://x.com/user13082000_/status/18027241739...  1.470000e+18
# 4     https://x.com/najaeminnesia/status/18012023710...  1.340000e+18
# ...                                                 ...           ...
# 1256  https://x.com/user13082000_/status/18180750710...  1.470000e+18
# 1257  https://x.com/Sailorneww/status/18180751175175...  4.739379e+08
# 1258    https://x.com/jlynrj/status/1818074066542272684  1.430000e+18
# 1259  https://x.com/ffrongg_/status/1818075085485523352  1.260000e+18
# 1260   https://x.com/Juvliae/status/1818075260652318896  1.700000e+18
#
#            username                                    translated_text
# 0         NCTsmtown  NARCISISM JAEMIN 1st PHOTO EXHIBITION OPEN 29 ...
# 1         NCTsmtown  First solo photo exhibition opens on June 29 D...
# 2        jamong1323  NARCISISM PHOTOGRAPHER NA JAEMIN 1st PHOTO EXH...
# 3     user13082000_  Jaemin got casted while voluntering and til th...
# 4     najaeminnesia  Mini Suprt Project for NARCISISM JAEMIN 1st PH...
# ...             ...                                                ...
# 1256  user13082000_                             NARCISISM BY NA JAEMIN
# 1257     Sailorneww                             NARCISISM BY NA JAEMIN
# 1258         jlynrj                        D 32 NARCISISM BY NA JAEMIN
# 1259       ffrongg_                             NARCISISM BY NA JAEMIN
# 1260        Juvliae  It s almost the end of the exhibition  I wil d...
#
# [1261 rows x 14 columns]

# %%
def preprocess_text(text):
    # Lowercase
    text = text.lower()
    
    # Tokenization
    words = text.split()
    
    # Stopwords removal
    stop_words = set(stopwords.words('english'))  # Ganti 'english' dengan bahasa yang sesuai
    words = [word for word in words if word not in stop_words]
    
    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    words = [lemmatizer.lemmatize(word) for word in words]
    
    # Join words back to text
    text = ' '.join(words)
    
    return text

# %%
df_clean['text'] = df_clean['translated_text'].apply(preprocess_text)

# %%
# Replacing short words
df_clean['text'] = df_clean['text'].apply(lambda x: ' '.join([w for w in x.split() if len(w)>2]))

# %%
# Kata-kata yang ingin dihapus
kata_dihapus = ['po', 'pre order', 'md', 'wtb', 'want to buy', 'iso', 'open', 'pre', 'shiping', 'ver', 'mention', 'tag', 'day', 'd23', 'freebies']

# Fungsi lambda untuk menghapus kata
def hapus_kata(text):
    for kata in kata_dihapus:
        text = text.replace(kata, '')
    return text

# Hapus kata-kata menggunakan lambda
df_clean['text'] = df_clean['text'].apply(hapus_kata)

# %%
df_clean
# Out:
#       Unnamed: 0  conversation_id_str                      created_at  \
# 0              0         1.800000e+18  Fri Jun 14 06:00:09 +0000 2024
# 1              1         1.800000e+18  Fri Jun 14 01:44:55 +0000 2024
# 2              2         1.800000e+18  Thu Jun 13 06:19:50 +0000 2024
# 3              3         1.800000e+18  Mon Jun 17 15:25:10 +0000 2024
# 4              4         1.800000e+18  Thu Jun 13 10:38:04 +0000 2024
# ...          ...                  ...                             ...
# 1256        1261         1.820000e+18  Tue Jul 30 00:04:09 +0000 2024
# 1257        1262         1.820000e+18  Tue Jul 30 00:04:20 +0000 2024
# 1258        1263         1.820000e+18  Tue Jul 30 00:00:10 +0000 2024
# 1259        1264         1.820000e+18  Tue Jul 30 00:04:13 +0000 2024
# 1260        1265         1.820000e+18  Tue Jul 30 00:04:55 +0000 2024
#
#       favorite_count                                          full_text  \
# 0              20853  NARCISSISM JAEMIN 1st PHOTO EXHIBITION OPEN 29...
# 1              46197  첫 개인 사진전 6월 29일오픈 사진 작가로 데뷔 재민의 독창적인 감성으로 팬들과 ...
# 2               1670  NARCISSISM PHOTOGRAPHER NA JAEMIN 1st PHOTO EX...
# 3               4855  Jaemin got casted while volunteering and till ...
# 4                288  Mini Suprt Project for NARCISSISM JAEMIN 1st P...
# ...              ...                                                ...
# 1256               0                            NARCISSISM BY NA JAEMIN
# 1257               0                            NARCISSISM BY NA JAEMIN
# 1258               0                       D 32 NARCISSISM BY NA JAEMIN
# 1259               0                            NARCISSISM BY NA JAEMIN
# 1260               0  ใกล้จะจบนิทรรศการแล้วค้าบบบ ต้องคิดถึงมากแน่ ๆ...
#
#             id_str lang  quote_count  reply_count  retweet_count  \
# 0     1.800000e+18   ko          355          475          13150
# 1     1.800000e+18   ko         3011         1600          27395
# 2     1.800000e+18   en           57            0           1023
# 3     1.800000e+18   en          109            8           2423
# 4     1.800000e+18   ko           32            1            255
# ...            ...  ...          ...          ...            ...
# 1256  1.820000e+18   tl            0            0              0
# 1257  1.820000e+18   tl            0            0              0
# 1258  1.820000e+18   tl            0            0              0
# 1259  1.820000e+18   tl            0            0              0
# 1260  1.820000e+18   th            0            0              0
#
#                                               tweet_url   user_id_str  \
# 0     https://x.com/NCTsmtown/status/180149481786990...  4.811011e+09
# 1     https://x.com/NCTsmtown/status/180143058501101...  4.811011e+09
# 2     https://x.com/jamong1323/status/18011373840522...  1.420000e+18
# 3     https://x.com/user13082000_/status/18027241739...  1.470000e+18
# 4     https://x.com/najaeminnesia/status/18012023710...  1.340000e+18
# ...                                                 ...           ...
# 1256  https://x.com/user13082000_/status/18180750710...  1.470000e+18
# 1257  https://x.com/Sailorneww/status/18180751175175...  4.739379e+08
# 1258    https://x.com/jlynrj/status/1818074066542272684  1.430000e+18
# 1259  https://x.com/ffrongg_/status/1818075085485523352  1.260000e+18
# 1260   https://x.com/Juvliae/status/1818075260652318896  1.700000e+18
#
#            username                                    translated_text  \
# 0         NCTsmtown  NARCISISM JAEMIN 1st PHOTO EXHIBITION OPEN 29 ...
# 1         NCTsmtown  First solo photo exhibition opens on June 29 D...
# 2        jamong1323  NARCISISM PHOTOGRAPHER NA JAEMIN 1st PHOTO EXH...
# 3     user13082000_  Jaemin got casted while voluntering and til th...
# 4     najaeminnesia  Mini Suprt Project for NARCISISM JAEMIN 1st PH...
# ...             ...                                                ...
# 1256  user13082000_                             NARCISISM BY NA JAEMIN
# 1257     Sailorneww                             NARCISISM BY NA JAEMIN
# 1258         jlynrj                        D 32 NARCISISM BY NA JAEMIN
# 1259       ffrongg_                             NARCISISM BY NA JAEMIN
# 1260        Juvliae  It s almost the end of the exhibition  I wil d...
#
#                                                    text
# 0     narcisism jaemin 1st photo exhibition  june 20...
# 1     first solo photo exhibition  june debut photog...
# 2     narcisism photographer jaemin 1st photo exhibi...
# 3     jaemin got casted voluntering til  stil contin...
# 4     mini suprt project narcisism jaemin 1st photo ...
# ...                                                 ...
# 1256                                   narcisism jaemin
# 1257                                   narcisism jaemin
# 1258                                   narcisism jaemin
# 1259                                   narcisism jaemin
# 1260  almost end exhibition wil definitely lot may s...
#
# [1261 rows x 15 columns]

# %% [markdown]
# ## Wordcloud

# %%
text = " ".join(df_clean['text'])
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
def get_sentiment(text):
    analysis = TextBlob(text)
    polarity = analysis.sentiment.polarity
    if polarity < -0.2:
        return 'negative'
    elif polarity > 0.2:
        return 'positive'
    else:
        return 'neutral'

df_clean['sentiment'] = df_clean['text'].apply(get_sentiment)
df_clean
# Out:
#       Unnamed: 0  conversation_id_str                      created_at  \
# 0              0         1.800000e+18  Fri Jun 14 06:00:09 +0000 2024
# 1              1         1.800000e+18  Fri Jun 14 01:44:55 +0000 2024
# 2              2         1.800000e+18  Thu Jun 13 06:19:50 +0000 2024
# 3              3         1.800000e+18  Mon Jun 17 15:25:10 +0000 2024
# 4              4         1.800000e+18  Thu Jun 13 10:38:04 +0000 2024
# ...          ...                  ...                             ...
# 1256        1261         1.820000e+18  Tue Jul 30 00:04:09 +0000 2024
# 1257        1262         1.820000e+18  Tue Jul 30 00:04:20 +0000 2024
# 1258        1263         1.820000e+18  Tue Jul 30 00:00:10 +0000 2024
# 1259        1264         1.820000e+18  Tue Jul 30 00:04:13 +0000 2024
# 1260        1265         1.820000e+18  Tue Jul 30 00:04:55 +0000 2024
#
#       favorite_count                                          full_text  \
# 0              20853  NARCISSISM JAEMIN 1st PHOTO EXHIBITION OPEN 29...
# 1              46197  첫 개인 사진전 6월 29일오픈 사진 작가로 데뷔 재민의 독창적인 감성으로 팬들과 ...
# 2               1670  NARCISSISM PHOTOGRAPHER NA JAEMIN 1st PHOTO EX...
# 3               4855  Jaemin got casted while volunteering and till ...
# 4                288  Mini Suprt Project for NARCISSISM JAEMIN 1st P...
# ...              ...                                                ...
# 1256               0                            NARCISSISM BY NA JAEMIN
# 1257               0                            NARCISSISM BY NA JAEMIN
# 1258               0                       D 32 NARCISSISM BY NA JAEMIN
# 1259               0                            NARCISSISM BY NA JAEMIN
# 1260               0  ใกล้จะจบนิทรรศการแล้วค้าบบบ ต้องคิดถึงมากแน่ ๆ...
#
#             id_str lang  quote_count  reply_count  retweet_count  \
# 0     1.800000e+18   ko          355          475          13150
# 1     1.800000e+18   ko         3011         1600          27395
# 2     1.800000e+18   en           57            0           1023
# 3     1.800000e+18   en          109            8           2423
# 4     1.800000e+18   ko           32            1            255
# ...            ...  ...          ...          ...            ...
# 1256  1.820000e+18   tl            0            0              0
# 1257  1.820000e+18   tl            0            0              0
# 1258  1.820000e+18   tl            0            0              0
# 1259  1.820000e+18   tl            0            0              0
# 1260  1.820000e+18   th            0            0              0
#
#                                               tweet_url   user_id_str  \
# 0     https://x.com/NCTsmtown/status/180149481786990...  4.811011e+09
# 1     https://x.com/NCTsmtown/status/180143058501101...  4.811011e+09
# 2     https://x.com/jamong1323/status/18011373840522...  1.420000e+18
# 3     https://x.com/user13082000_/status/18027241739...  1.470000e+18
# 4     https://x.com/najaeminnesia/status/18012023710...  1.340000e+18
# ...                                                 ...           ...
# 1256  https://x.com/user13082000_/status/18180750710...  1.470000e+18
# 1257  https://x.com/Sailorneww/status/18180751175175...  4.739379e+08
# 1258    https://x.com/jlynrj/status/1818074066542272684  1.430000e+18
# 1259  https://x.com/ffrongg_/status/1818075085485523352  1.260000e+18
# 1260   https://x.com/Juvliae/status/1818075260652318896  1.700000e+18
#
#            username                                    translated_text  \
# 0         NCTsmtown  NARCISISM JAEMIN 1st PHOTO EXHIBITION OPEN 29 ...
# 1         NCTsmtown  First solo photo exhibition opens on June 29 D...
# 2        jamong1323  NARCISISM PHOTOGRAPHER NA JAEMIN 1st PHOTO EXH...
# 3     user13082000_  Jaemin got casted while voluntering and til th...
# 4     najaeminnesia  Mini Suprt Project for NARCISISM JAEMIN 1st PH...
# ...             ...                                                ...
# 1256  user13082000_                             NARCISISM BY NA JAEMIN
# 1257     Sailorneww                             NARCISISM BY NA JAEMIN
# 1258         jlynrj                        D 32 NARCISISM BY NA JAEMIN
# 1259       ffrongg_                             NARCISISM BY NA JAEMIN
# 1260        Juvliae  It s almost the end of the exhibition  I wil d...
#
#                                                    text sentiment
# 0     narcisism jaemin 1st photo exhibition  june 20...   neutral
# 1     first solo photo exhibition  june debut photog...  positive
# 2     narcisism photographer jaemin 1st photo exhibi...   neutral
# 3     jaemin got casted voluntering til  stil contin...  positive
# 4     mini suprt project narcisism jaemin 1st photo ...   neutral
# ...                                                 ...       ...
# 1256                                   narcisism jaemin   neutral
# 1257                                   narcisism jaemin   neutral
# 1258                                   narcisism jaemin   neutral
# 1259                                   narcisism jaemin   neutral
# 1260  almost end exhibition wil definitely lot may s...   neutral
#
# [1261 rows x 16 columns]

# %%
df_clean['sentiment'].value_counts()
# Out:
# sentiment
# neutral     893
# positive    347
# negative     21
# Name: count, dtype: int64

# %%
analyzer = SentimentIntensityAnalyzer()

df_clean['compound'] = [analyzer.polarity_scores(x)['compound'] for x in df_clean['text']]
df_clean['neg'] = [analyzer.polarity_scores(x)['neg'] for x in df_clean['text']]
df_clean['neu'] = [analyzer.polarity_scores(x)['neu'] for x in df_clean['text']]
df_clean['pos'] = [analyzer.polarity_scores(x)['pos'] for x in df_clean['text']]

df_clean
# Out:
#       Unnamed: 0  conversation_id_str                      created_at  \
# 0              0         1.800000e+18  Fri Jun 14 06:00:09 +0000 2024
# 1              1         1.800000e+18  Fri Jun 14 01:44:55 +0000 2024
# 2              2         1.800000e+18  Thu Jun 13 06:19:50 +0000 2024
# 3              3         1.800000e+18  Mon Jun 17 15:25:10 +0000 2024
# 4              4         1.800000e+18  Thu Jun 13 10:38:04 +0000 2024
# ...          ...                  ...                             ...
# 1256        1261         1.820000e+18  Tue Jul 30 00:04:09 +0000 2024
# 1257        1262         1.820000e+18  Tue Jul 30 00:04:20 +0000 2024
# 1258        1263         1.820000e+18  Tue Jul 30 00:00:10 +0000 2024
# 1259        1264         1.820000e+18  Tue Jul 30 00:04:13 +0000 2024
# 1260        1265         1.820000e+18  Tue Jul 30 00:04:55 +0000 2024
#
#       favorite_count                                          full_text  \
# 0              20853  NARCISSISM JAEMIN 1st PHOTO EXHIBITION OPEN 29...
# 1              46197  첫 개인 사진전 6월 29일오픈 사진 작가로 데뷔 재민의 독창적인 감성으로 팬들과 ...
# 2               1670  NARCISSISM PHOTOGRAPHER NA JAEMIN 1st PHOTO EX...
# 3               4855  Jaemin got casted while volunteering and till ...
# 4                288  Mini Suprt Project for NARCISSISM JAEMIN 1st P...
# ...              ...                                                ...
# 1256               0                            NARCISSISM BY NA JAEMIN
# 1257               0                            NARCISSISM BY NA JAEMIN
# 1258               0                       D 32 NARCISSISM BY NA JAEMIN
# 1259               0                            NARCISSISM BY NA JAEMIN
# 1260               0  ใกล้จะจบนิทรรศการแล้วค้าบบบ ต้องคิดถึงมากแน่ ๆ...
#
#             id_str lang  quote_count  reply_count  retweet_count  \
# 0     1.800000e+18   ko          355          475          13150
# 1     1.800000e+18   ko         3011         1600          27395
# 2     1.800000e+18   en           57            0           1023
# 3     1.800000e+18   en          109            8           2423
# 4     1.800000e+18   ko           32            1            255
# ...            ...  ...          ...          ...            ...
# 1256  1.820000e+18   tl            0            0              0
# 1257  1.820000e+18   tl            0            0              0
# 1258  1.820000e+18   tl            0            0              0
# 1259  1.820000e+18   tl            0            0              0
# 1260  1.820000e+18   th            0            0              0
#
#                                               tweet_url   user_id_str  \
# 0     https://x.com/NCTsmtown/status/180149481786990...  4.811011e+09
# 1     https://x.com/NCTsmtown/status/180143058501101...  4.811011e+09
# 2     https://x.com/jamong1323/status/18011373840522...  1.420000e+18
# 3     https://x.com/user13082000_/status/18027241739...  1.470000e+18
# 4     https://x.com/najaeminnesia/status/18012023710...  1.340000e+18
# ...                                                 ...           ...
# 1256  https://x.com/user13082000_/status/18180750710...  1.470000e+18
# 1257  https://x.com/Sailorneww/status/18180751175175...  4.739379e+08
# 1258    https://x.com/jlynrj/status/1818074066542272684  1.430000e+18
# 1259  https://x.com/ffrongg_/status/1818075085485523352  1.260000e+18
# 1260   https://x.com/Juvliae/status/1818075260652318896  1.700000e+18
#
#            username                                    translated_text  \
# 0         NCTsmtown  NARCISISM JAEMIN 1st PHOTO EXHIBITION OPEN 29 ...
# 1         NCTsmtown  First solo photo exhibition opens on June 29 D...
# 2        jamong1323  NARCISISM PHOTOGRAPHER NA JAEMIN 1st PHOTO EXH...
# 3     user13082000_  Jaemin got casted while voluntering and til th...
# 4     najaeminnesia  Mini Suprt Project for NARCISISM JAEMIN 1st PH...
# ...             ...                                                ...
# 1256  user13082000_                             NARCISISM BY NA JAEMIN
# 1257     Sailorneww                             NARCISISM BY NA JAEMIN
# 1258         jlynrj                        D 32 NARCISISM BY NA JAEMIN
# 1259       ffrongg_                             NARCISISM BY NA JAEMIN
# 1260        Juvliae  It s almost the end of the exhibition  I wil d...
#
#                                                    text sentiment  compound  \
# 0     narcisism jaemin 1st photo exhibition  june 20...   neutral    0.0000
# 1     first solo photo exhibition  june debut photog...  positive    0.3182
# 2     narcisism photographer jaemin 1st photo exhibi...   neutral    0.0000
# 3     jaemin got casted voluntering til  stil contin...  positive    0.6369
# 4     mini suprt project narcisism jaemin 1st photo ...   neutral    0.0000
# ...                                                 ...       ...       ...
# 1256                                   narcisism jaemin   neutral    0.0000
# 1257                                   narcisism jaemin   neutral    0.0000
# 1258                                   narcisism jaemin   neutral    0.0000
# 1259                                   narcisism jaemin   neutral    0.0000
# 1260  almost end exhibition wil definitely lot may s...   neutral    0.4019
#
#       neg    neu    pos
# 0     0.0  1.000  0.000
# 1     0.0  0.881  0.119
# 2     0.0  1.000  0.000
# 3     0.0  0.704  0.296
# 4     0.0  1.000  0.000
# ...   ...    ...    ...
# 1256  0.0  1.000  0.000
# 1257  0.0  1.000  0.000
# 1258  0.0  1.000  0.000
# 1259  0.0  1.000  0.000
# 1260  0.0  0.769  0.231
#
# [1261 rows x 20 columns]

# %% [markdown]
# The compound score is a metric that calculates the sum of all the ratings which have been normalized between -1 (most extreme negative) and +1 (most extreme positive).
#
# - positive sentiment : compound score greater than 0.05
# - neutral sentiment : compound score between -0.05 and 0.05
# - negative sentiment : compound score less than -0.05
#
# Let's examine the distribution of sentiment.

# %%
# Extract Figure and Axes instance
fig, (ax1, ax2, ax3, ax4) = plt.subplots(nrows=1, ncols=4)

# Create plots showing distribution
ax1.violinplot(df_clean.compound)
ax1.set_title('Compound')

ax2.violinplot(df_clean.neg)
ax2.set_title('Negative')

ax3.violinplot(df_clean.neu)
ax3.set_title('Neutral')

ax4.violinplot(df_clean.pos)
ax4.set_title('Positive')

# Display settings
fig.suptitle('Distribution of Sentiment in Jaemin 1st Photo Exhibition Dataset')
fig.tight_layout()
plt.show()

# %%
bow_vectorizer = CountVectorizer()
bow_features = bow_vectorizer.fit_transform(df_clean['text'])

# %%
# Term Frequency-Inverse Document Frequency (TF-IDF) Model
tfidf_vectorizer = TfidfVectorizer()
tfidf_features = tfidf_vectorizer.fit_transform(df_clean['text'])

# %%
# Assuming df_clean['text'] contains the cleaned text data
word2vec_model = Word2Vec(sentences=[word_tokenize(text) for text in df_clean['text']], vector_size=100, window=5, min_count=1, workers=4)

def get_word_vector(word):
    if word in word2vec_model.wv:
        return word2vec_model.wv[word]
    else:
        return np.zeros(100)  # Return zero vector if word not found

word2vec_features = []
for text in df_clean['text']:
    word_vectors = [get_word_vector(word) for word in word_tokenize(text)]
    if word_vectors:  # Check if the list is not empty
        word2vec_features.append(np.mean(word_vectors, axis=0))
    else:
        word2vec_features.append(np.zeros(100))  # Handle empty tokenized lists

word2vec_features = np.array(word2vec_features)

# %%
y = df_clean.sentiment.values

# %%
# Splitting the dataset into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(bow_features, y, test_size = 0.20, random_state = 0)

# Logistic Regression Model
lr_model = LogisticRegression()
lr_model.fit(X_train, y_train)

# Evaluate the model
y_pred = lr_model.predict(X_test)

f1_score_lr = f1_score(y_test, y_pred, average='weighted')
print("F1 Score (Logistic Regression):", f1_score_lr)
# Out:
# F1 Score (Logistic Regression): 0.8878431495896174

# %%
# Splitting the dataset into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(tfidf_features, y, test_size = 0.20, random_state = 0)

# Logistic Regression Model
lr_model = LogisticRegression()
lr_model.fit(X_train, y_train)

# Evaluate the model
y_pred = lr_model.predict(X_test)

f1_score_lr = f1_score(y_test, y_pred, average='weighted')
print("F1 Score (Logistic Regression):", f1_score_lr)
# Out:
# F1 Score (Logistic Regression): 0.8605498335823046

# %%
# Splitting the dataset into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(word2vec_features, y, test_size = 0.20, random_state = 0)

# Logistic Regression Model
lr_model = LogisticRegression()
lr_model.fit(X_train, y_train)

# Evaluate the model
y_pred = lr_model.predict(X_test)

f1_score_lr = f1_score(y_test, y_pred, average='weighted')
print("F1 Score (Logistic Regression):", f1_score_lr)
# Out:
# F1 Score (Logistic Regression): 0.617701734437887

# %%
svm_model = SVC(kernel='linear')
svm_model.fit(X_train, y_train)

# Evaluate the model
y_pred_svm = svm_model.predict(X_test)
f1_score_svm = f1_score(y_test, y_pred_svm,average='weighted')
print("F1 Score (SVM):", f1_score_svm)
# Out:
# F1 Score (SVM): 0.617701734437887

# %%
svm_model = SVC(kernel='rbf')
svm_model.fit(X_train, y_train)

# Evaluate the model
y_pred_svm = svm_model.predict(X_test)
f1_score_svm = f1_score(y_test, y_pred_svm,average='weighted')
print("F1 Score (SVM):", f1_score_svm)
# Out:
# F1 Score (SVM): 0.617701734437887

# %%
svm_model = SVC(kernel='sigmoid')
svm_model.fit(X_train, y_train)

# Evaluate the model
y_pred_svm = svm_model.predict(X_test)
f1_score_svm = f1_score(y_test, y_pred_svm,average='weighted')
print("F1 Score (SVM):", f1_score_svm)
# Out:
# F1 Score (SVM): 0.5364462922912473

# %%
svm_model = SVC(kernel='poly', degree = 10)
svm_model.fit(X_train, y_train)

# Evaluate the model
y_pred_svm = svm_model.predict(X_test)
f1_score_svm = f1_score(y_test, y_pred_svm,average='weighted')
print("F1 Score (SVM):", f1_score_svm)
# Out:
# F1 Score (SVM): 0.62689489950459

# %%
classifier = GaussianNB()
classifier.fit(X_train, y_train)

y_pred_gaus = classifier.predict(X_test)
f1_score_gaus = f1_score(y_test, y_pred_gaus,average='weighted')
print("F1 Score (GaussianNB):", f1_score_gaus)
# Out:
# F1 Score (GaussianNB): 0.5523615511170968

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(bow_features, y, test_size=0.20, random_state=42)

# Convert sparse matrices to dense
X_train_dense = X_train.toarray()
X_test_dense = X_test.toarray()

# Example label mapping for multi-class classification
label_mapping = {
    'positive': 2,
    'neutral': 1,
    'negative': 0
}

# Assuming y_train and y_test are numpy arrays with sentiment labels
y_train_series = pd.Series(y_train)
y_test_series = pd.Series(y_test)

# Map the sentiment labels to numeric values
y_train_mapped = y_train_series.map(label_mapping)
y_test_mapped = y_test_series.map(label_mapping)

# Convert the mapped Series back to numpy arrays
y_train_mapped = np.array(y_train_mapped, dtype=np.int32)
y_test_mapped = np.array(y_test_mapped, dtype=np.int32)

# One-hot encode the labels
y_train_onehot = to_categorical(y_train_mapped, num_classes=3)
y_test_onehot = to_categorical(y_test_mapped, num_classes=3)

# Ensure feature matrices are in float format
X_train_dense = np.array(X_train_dense, dtype=np.float32)
X_test_dense = np.array(X_test_dense, dtype=np.float32)

# Define a simple neural network model for multi-class classification
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(128, input_dim=X_train_dense.shape[1], activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(3, activation='softmax'))  # 3 output classes

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X_train_dense, y_train_onehot, epochs=10, batch_size=32, validation_data=(X_test_dense, y_test_onehot))
# Out:
# Epoch 1/10
# 32/32 [==============================] - 1s 10ms/step - loss: 0.8740 - accuracy: 0.7024 - val_loss: 0.6915 - val_accuracy: 0.6719
# Epoch 2/10
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4955 - accuracy: 0.8274 - val_loss: 0.5219 - val_accuracy: 0.7628
# Epoch 3/10
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2523 - accuracy: 0.9335 - val_loss: 0.4095 - val_accuracy: 0.8617
# Epoch 4/10
# 32/32 [==============================] - 0s 7ms/step - loss: 0.1203 - accuracy: 0.9683 - val_loss: 0.4010 - val_accuracy: 0.8775
# Epoch 5/10
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0693 - accuracy: 0.9792 - val_loss: 0.4310 - val_accuracy: 0.8735
# Epoch 6/10
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0455 - accuracy: 0.9861 - val_loss: 0.4754 - val_accuracy: 0.8775
# Epoch 7/10
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0296 - accuracy: 0.9950 - val_loss: 0.4978 - val_accuracy: 0.8775
# Epoch 8/10
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0183 - accuracy: 0.9980 - val_loss: 0.5463 - val_accuracy: 0.8775
# Epoch 9/10
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0115 - accuracy: 0.9980 - val_loss: 0.5782 - val_accuracy: 0.8775
# Epoch 10/10
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0076 - accuracy: 0.9990 - val_loss: 0.6064 - val_accuracy: 0.8814

# %%
# Evaluate the model using F1-Score
y_pred = model.predict(X_test_dense)

# Get the class with the highest probability
y_pred_class = np.argmax(y_pred, axis=1)

# Compute the F1-Score
f1 = f1_score(y_test_mapped, y_pred_class, average='weighted')
print("F1-Score:", f1)
# Out:
# 8/8 [==============================] - 0s 3ms/step
# F1-Score: 0.8725503170202609
